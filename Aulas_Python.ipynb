# %% [markdown]
# <a href="https://colab.research.google.com/github/dacasfilipe/aulas_python/blob/main/Aulas_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Aula 1: Introdução ao Python
#
# #### Objetivos
# - Apresentar o que é Python
# - Guia para instalação e configuração do ambiente
#
# #### Conteúdo
#
# 1. **O que é Python?**
#    - Linguagem de alto nível
#    - Aplicações diversas: web, ciência de dados, automação, etc.
#
# 2. **Instalação**
#    - Windows: Usar o instalador da python.org
#    - MacOS e Linux: Usar o gerenciador de pacotes ou instalar via python.org
#
# 3. **Ambiente de Desenvolvimento**
#    - IDEs populares: PyCharm, Jupyter Notebook
#    - Uso do terminal ou prompt de comando
#
# #### Exercício
# - Instale Python e configure seu ambiente de desenvolvimento.
#
# #### Material Adicional
# - [Documentação Oficial](https://www.python.org/doc/)
#
# ---
#
# ### Aula 2: Sintaxe Básica
#
# #### Objetivos
# - Apresentar a sintaxe básica
# - Introduzir variáveis e tipos de dados
#
# #### Conteúdo
#
# 1. **Sintaxe**
#    - Indentação
#    - Comentários
#
# 2. **Variáveis e Tipos de Dados**
#    - Números (int, float)
#    - Strings
#    - Booleanos
#
# #### Exercício
# - Crie variáveis de diferentes tipos e exiba seus valores e tipos.
#
# #### Material Adicional
# - [W3Schools Python Syntax](https://www.w3schools.com/python/python_syntax.asp)
#
# ---
#
# ### Aula 3: Estruturas de Controle
#
# #### Objetivos
# - Ensinar estruturas condicionais
# - Introduzir loops
#
# #### Conteúdo
#
# 1. **Estruturas Condicionais**
#    - `if`
#    - `else`
#    - `elif`
#
# 2. **Loops**
#    - `for`
#    - `while`
#
# #### Exercício
# - Escreva um programa para calcular as notas de um aluno.
#
# #### Material Adicional
# - [Python If ... Else (W3Schools)](https://www.w3schools.com/python/python_conditions.asp)
#
# ---
#
# ### Aula 4: Funções e Módulos
#
# #### Objetivos
# - Apresentar a definição e uso de funções
# - Ensinar como importar módulos
#
# #### Conteúdo
#
# 1. **Funções**
#    - Definição
#    - Parâmetros
#    - Retorno
#
# 2. **Módulos**
#    - `import`
#    - Uso de módulos padrão como `math`, `datetime`
#
# #### Exercício
# - Crie uma função para calcular o IMC (Índice de Massa Corporal) e outra para converter temperaturas entre Celsius e Fahrenheit.
#
# #### Material Adicional
# - [Defining Functions (Python.org)](https://docs.python.org/3/tutorial/controlflow.html#defining-functions)
#
#
# ---
#
# ### Aula 5: Estruturas de Dados
#
# #### Objetivos
# - Introduzir listas e tuplas
# - Ensinar dicionários e conjuntos
#
# #### Conteúdo
#
# 1. **Listas e Tuplas**
#    - Criação e acesso
#    - Métodos como `append()`, `pop()`
#
# 2. **Dicionários e Conjuntos**
#    - Sintaxe e uso
#    - Manipulação de chaves e valores
#
# #### Exercício
# - Crie um programa para gerenciar uma lista de contatos usando dicionários.
#
# #### Material Adicional
# - [Python Data Structures (W3Schools)](https://www.w3schools.com/python/python_lists.asp)
#
# ---
#
# ### Aula 6: Manipulação de Arquivos
#
# #### Objetivos
# - Ensinar como ler e escrever arquivos
#
# #### Conteúdo
#
# 1. **Ler Arquivos**
#    - `open()`, `read()`, `readline()`
#
# 2. **Escrever Arquivos**
#    - `write()`, `writelines()`
#
# #### Exercício
# - Crie um programa que leia um arquivo de texto e conte o número de palavras.
#
# #### Material Adicional
# - [Reading and Writing Files (Python.org)](https://docs.python.org/3/tutorial/inputoutput.html#reading-and-writing-files)
#
# ---
#
# ### Aula 7: Programação Orientada a Objetos
#
# #### Objetivos
# - Introduzir classes e objetos
# - Ensinar herança e polimorfismo
#
# #### Conteúdo
#
# 1. **Classes e Objetos**
#    - Definição e instanciação
#    - Atributos e métodos
#
# 2. **Herança e Polimorfismo**
#    - Sintaxe e uso
#
# #### Exercício
# - Crie uma classe para modelar um carro com métodos para acelerar e frear.
#
# #### Material Adicional
# - [Python Classes (W3Schools)](https://www.w3schools.com/python/python_classes.asp)
#
# ---
#
# ### Aula 8: Bibliotecas Populares
#
# #### Objetivos
# - Apresentar bibliotecas como NumPy, Pandas e Matplotlib
#
# #### Conteúdo
#
# 1. **NumPy**
#    - Arrays e matrizes
#    - Operações básicas
#
# 2. **Pandas**
#    - DataFrames
#    - Manipulação de dados
#
# 3. **Matplotlib**
#    - Criação de gráficos
#    - Visualização de dados
#
# #### Exercício
# - Use Pandas para ler um conjunto de dados e Matplotlib para visualizá-lo.
#
# #### Material Adicional
# - [NumPy Quickstart](https://numpy.org/doc/stable/user/quickstart.html)
# - [Pandas Documentation](https://pandas.pydata.org/docs/)
# - [Matplotlib Tutorials](https://matplotlib.org/stable/tutorials/index.html)
#
# ---
#
# ### Aula 9: Projetos Práticos
#
# #### Objetivos
# - Aplicar o conhecimento adquirido em projetos práticos
#
# #### Conteúdo
#
# 1. **Web Scraping**
#    - Uso da biblioteca `BeautifulSoup`
#
# 2. **Automatização de Tarefas**
#    - Uso de `selenium` ou `pyautogui`
#
# 3. **Desenvolvimento de Web Apps**
#    - Introdução ao Flask
#
# #### Exercício
# - Escolha um projeto prático e implemente-o.
#
# #### Material Adicional
# - [BeautifulSoup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Selenium Documentation](https://www.selenium.dev/documentation/en/)
# - [Flask Tutorial](https://flask.palletsprojects.com/en/2.0.x/tutorial/)
#
# ---
#
# ### Aula 10: Exame Final e Avaliação
#
# #### Objetivos
# - Avaliar o conhecimento adquirido pelos alunos
#
# #### Conteúdo
# - Exame escrito
# - Projeto prático
#
# #### Exercício
# - Complete o exame e o projeto prático.
#
# #### Material Adicional
# - Revisão de todas as aulas anteriores
